# %% [markdown]
# <a href="https://colab.research.google.com/github/ZiadMAlsawy/ML_Project/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #All import needed

# %%
#from google.colab import drive

import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsRegressor

from sklearn.linear_model import LinearRegression

from sklearn.linear_model import LogisticRegression

from sklearn.linear_model import Ridge

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import mean_squared_error

from sklearn.metrics import root_mean_squared_error

from sklearn.metrics import mean_absolute_error

from sklearn.metrics import accuracy_score

from sklearn.metrics import precision_score

from sklearn.metrics import recall_score

from sklearn.metrics import f1_score

from sklearn.metrics import precision_recall_curve

from sklearn.metrics import r2_score

from scipy.stats import skew

from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import LabelEncoder

from sklearn.preprocessing import RobustScaler

# %% [markdown]
# #DataSet Loading

# %%
#drive.mount("/content/drive")
loan = pd.read_csv("Loan.csv")

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Make a copy of the dataset

# %%
copy = loan.copy()

# %% [markdown]
# Describe Data

# %%
copy.describe()
# Out:
#                 Age   AnnualIncome   CreditScore    Experience     LoanAmount  \
# count  20000.000000   20000.000000  20000.000000  20000.000000   20000.000000
# mean      39.752600   59161.473550    571.612400     17.522750   24882.867800
# std       11.622713   40350.845168     50.997358     11.316836   13427.421217
# min       18.000000   15000.000000    343.000000      0.000000    3674.000000
# 25%       32.000000   31679.000000    540.000000      9.000000   15575.000000
# 50%       40.000000   48566.000000    578.000000     17.000000   21914.500000
# 75%       48.000000   74391.000000    609.000000     25.000000   30835.000000
# max       80.000000  485341.000000    712.000000     61.000000  184732.000000
#
#        LoanDuration  NumberOfDependents  MonthlyDebtPayments  \
# count  20000.000000        20000.000000         20000.000000
# mean      54.057000            1.517300           454.292700
# std       24.664857            1.386325           240.507609
# min       12.000000            0.000000            50.000000
# 25%       36.000000            0.000000           286.000000
# 50%       48.000000            1.000000           402.000000
# 75%       72.000000            2.000000           564.000000
# max      120.000000            5.000000          2919.000000
#
#        CreditCardUtilizationRate  NumberOfOpenCreditLines  ...  MonthlyIncome  \
# count               20000.000000             20000.000000  ...   20000.000000
# mean                    0.286381                 3.023350  ...    4891.715521
# std                     0.159793                 1.736161  ...    3296.771598
# min                     0.000974                 0.000000  ...    1250.000000
# 25%                     0.160794                 2.000000  ...    2629.583333
# 50%                     0.266673                 3.000000  ...    4034.750000
# 75%                     0.390634                 4.000000  ...    6163.000000
# max                     0.917380                13.000000  ...   25000.000000
#
#        UtilityBillsPaymentHistory     JobTenure      NetWorth  \
# count                20000.000000  20000.000000  2.000000e+04
# mean                     0.799918      5.002650  7.229432e+04
# std                      0.120665      2.236804  1.179200e+05
# min                      0.259203      0.000000  1.000000e+03
# 25%                      0.727379      3.000000  8.734750e+03
# 50%                      0.820962      5.000000  3.285550e+04
# 75%                      0.892333      6.000000  8.882550e+04
# max                      0.999433     16.000000  2.603208e+06
#
#        BaseInterestRate  InterestRate  MonthlyLoanPayment  \
# count      20000.000000  20000.000000        20000.000000
# mean           0.239124      0.239110          911.607052
# std            0.035509      0.042205          674.583473
# min            0.130101      0.113310           97.030193
# 25%            0.213889      0.209142          493.763700
# 50%            0.236157      0.235390          728.511452
# 75%            0.261533      0.265532         1112.770759
# max            0.405029      0.446787        10892.629520
#
#        TotalDebtToIncomeRatio  LoanApproved     RiskScore
# count            20000.000000  20000.000000  20000.000000
# mean                 0.402182      0.239000     50.766780
# std                  0.338924      0.426483      7.778262
# min                  0.016043      0.000000     28.800000
# 25%                  0.179693      0.000000     46.000000
# 50%                  0.302711      0.000000     52.000000
# 75%                  0.509214      0.000000     56.000000
# max                  4.647657      1.000000     84.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# Shape of data

# %%
copy.shape
# Out:
# (20000, 36)

# %% [markdown]
# Columns Types

# %%
copy.dtypes
# Out:
# ApplicationDate                object
# Age                             int64
# AnnualIncome                    int64
# CreditScore                     int64
# EmploymentStatus               object
# EducationLevel                 object
# Experience                      int64
# LoanAmount                      int64
# LoanDuration                    int64
# MaritalStatus                  object
# NumberOfDependents              int64
# HomeOwnershipStatus            object
# MonthlyDebtPayments             int64
# CreditCardUtilizationRate     float64
# NumberOfOpenCreditLines         int64
# NumberOfCreditInquiries         int64
# DebtToIncomeRatio             float64
# BankruptcyHistory               int64
# LoanPurpose                    object
# PreviousLoanDefaults            int64
# PaymentHistory                  int64
# LengthOfCreditHistory           int64
# SavingsAccountBalance           int64
# CheckingAccountBalance          int64
# TotalAssets                     int64
# TotalLiabilities                int64
# MonthlyIncome                 float64
# UtilityBillsPaymentHistory    float64
# JobTenure                       int64
# NetWorth                        int64
# BaseInterestRate              float64
# InterestRate                  float64
# MonthlyLoanPayment            float64
# TotalDebtToIncomeRatio        float64
# LoanApproved                    int64
# RiskScore                     float64
# dtype: object

# %% [markdown]
# Handling Missing Data

# %%
copy.isna().sum()
# Out:
# ApplicationDate               0
# Age                           0
# AnnualIncome                  0
# CreditScore                   0
# EmploymentStatus              0
# EducationLevel                0
# Experience                    0
# LoanAmount                    0
# LoanDuration                  0
# MaritalStatus                 0
# NumberOfDependents            0
# HomeOwnershipStatus           0
# MonthlyDebtPayments           0
# CreditCardUtilizationRate     0
# NumberOfOpenCreditLines       0
# NumberOfCreditInquiries       0
# DebtToIncomeRatio             0
# BankruptcyHistory             0
# LoanPurpose                   0
# PreviousLoanDefaults          0
# PaymentHistory                0
# LengthOfCreditHistory         0
# SavingsAccountBalance         0
# CheckingAccountBalance        0
# TotalAssets                   0
# TotalLiabilities              0
# MonthlyIncome                 0
# UtilityBillsPaymentHistory    0
# JobTenure                     0
# NetWorth                      0
# BaseInterestRate              0
# InterestRate                  0
# MonthlyLoanPayment            0
# TotalDebtToIncomeRatio        0
# LoanApproved                  0
# RiskScore                     0
# dtype: int64

# %% [markdown]
# Handle duplicates

# %%
copy.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Dropping Unnessary columns

# %%
copy = copy.drop(columns = "ApplicationDate")
copy.drop_duplicates()
copy.dropna()
# Out:
#        Age  AnnualIncome  CreditScore EmploymentStatus EducationLevel  \
# 0       45         39948          617         Employed         Master
# 1       38         39709          628         Employed      Associate
# 2       47         40724          570         Employed       Bachelor
# 3       58         69084          545         Employed    High School
# 4       37        103264          594         Employed      Associate
# ...    ...           ...          ...              ...            ...
# 19995   44         30180          587         Employed    High School
# 19996   56         49246          567         Employed      Associate
# 19997   44         48958          645         Employed       Bachelor
# 19998   60         41025          560         Employed    High School
# 19999   20         53227          574         Employed      Associate
#
#        Experience  LoanAmount  LoanDuration MaritalStatus  NumberOfDependents  \
# 0              22       13152            48       Married                   2
# 1              15       26045            48        Single                   1
# 2              26       17627            36       Married                   2
# 3              34       37898            96        Single                   1
# 4              17        9184            36       Married                   1
# ...           ...         ...           ...           ...                 ...
# 19995          19       24521            36       Married                   3
# 19996          33       25818            36       Married                   5
# 19997          20       37033            72       Married                   3
# 19998          36       14760            72       Married                   3
# 19999           0       32055            48       Married                   0
#
#        ... MonthlyIncome  UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# 0      ...   3329.000000                    0.724972         11    126928
# 1      ...   3309.083333                    0.935132          3     43609
# 2      ...   3393.666667                    0.872241          6      5205
# 3      ...   5757.000000                    0.896155          5     99452
# 4      ...   8605.333333                    0.941369          5    227019
# ...    ...           ...                         ...        ...       ...
# 19995  ...   2515.000000                    0.826217          1     55327
# 19996  ...   4103.833333                    0.816618          3     64002
# 19997  ...   4079.833333                    0.887216          3    103663
# 19998  ...   3418.750000                    0.843787          5     10600
# 19999  ...   4435.583333                    0.853801          5     41372
#
#        BaseInterestRate  InterestRate  MonthlyLoanPayment  \
# 0              0.199652      0.227590          419.805992
# 1              0.207045      0.201077          794.054238
# 2              0.217627      0.212548          666.406688
# 3              0.300398      0.300911         1047.506980
# 4              0.197184      0.175990          330.179140
# ...                 ...           ...                 ...
# 19995          0.216021      0.195574          905.767712
# 19996          0.227318      0.199168          958.395633
# 19997          0.229533      0.226766          945.427454
# 19998          0.249760      0.264873          411.168284
# 19999          0.240055      0.242693         1049.830407
#
#       TotalDebtToIncomeRatio  LoanApproved  RiskScore
# 0                   0.181077             0       49.0
# 1                   0.389852             0       52.0
# 2                   0.462157             0       52.0
# 3                   0.313098             0       54.0
# 4                   0.070210             1       36.0
# ...                      ...           ...        ...
# 19995               0.627741             0       55.0
# 19996               0.334418             0       54.0
# 19997               0.357227             0       45.0
# 19998               0.408678             0       59.0
# 19999               0.298006             0       59.0
#
# [20000 rows x 35 columns]

# %% [markdown]
# Handle Categorical Features

# %%
listOfColumns = []

listOfCategoricalColumns = []
for i in copy.select_dtypes(include = 'number'):
    listOfColumns.append(i)


for j in copy.columns:

    if j not in listOfColumns:
        listOfCategoricalColumns.append(j)
le = LabelEncoder()
for i in listOfCategoricalColumns:
    copy[i] = le.fit_transform(copy[i])


copy
# Out:
#        Age  AnnualIncome  CreditScore  EmploymentStatus  EducationLevel  \
# 0       45         39948          617                 0               4
# 1       38         39709          628                 0               0
# 2       47         40724          570                 0               1
# 3       58         69084          545                 0               3
# 4       37        103264          594                 0               0
# ...    ...           ...          ...               ...             ...
# 19995   44         30180          587                 0               3
# 19996   56         49246          567                 0               0
# 19997   44         48958          645                 0               1
# 19998   60         41025          560                 0               3
# 19999   20         53227          574                 0               0
#
#        Experience  LoanAmount  LoanDuration  MaritalStatus  \
# 0              22       13152            48              1
# 1              15       26045            48              2
# 2              26       17627            36              1
# 3              34       37898            96              2
# 4              17        9184            36              1
# ...           ...         ...           ...            ...
# 19995          19       24521            36              1
# 19996          33       25818            36              1
# 19997          20       37033            72              1
# 19998          36       14760            72              1
# 19999           0       32055            48              1
#
#        NumberOfDependents  ...  MonthlyIncome  UtilityBillsPaymentHistory  \
# 0                       2  ...    3329.000000                    0.724972
# 1                       1  ...    3309.083333                    0.935132
# 2                       2  ...    3393.666667                    0.872241
# 3                       1  ...    5757.000000                    0.896155
# 4                       1  ...    8605.333333                    0.941369
# ...                   ...  ...            ...                         ...
# 19995                   3  ...    2515.000000                    0.826217
# 19996                   5  ...    4103.833333                    0.816618
# 19997                   3  ...    4079.833333                    0.887216
# 19998                   3  ...    3418.750000                    0.843787
# 19999                   0  ...    4435.583333                    0.853801
#
#        JobTenure  NetWorth  BaseInterestRate  InterestRate  \
# 0             11    126928          0.199652      0.227590
# 1              3     43609          0.207045      0.201077
# 2              6      5205          0.217627      0.212548
# 3              5     99452          0.300398      0.300911
# 4              5    227019          0.197184      0.175990
# ...          ...       ...               ...           ...
# 19995          1     55327          0.216021      0.195574
# 19996          3     64002          0.227318      0.199168
# 19997          3    103663          0.229533      0.226766
# 19998          5     10600          0.249760      0.264873
# 19999          5     41372          0.240055      0.242693
#
#        MonthlyLoanPayment  TotalDebtToIncomeRatio  LoanApproved  RiskScore
# 0              419.805992                0.181077             0       49.0
# 1              794.054238                0.389852             0       52.0
# 2              666.406688                0.462157             0       52.0
# 3             1047.506980                0.313098             0       54.0
# 4              330.179140                0.070210             1       36.0
# ...                   ...                     ...           ...        ...
# 19995          905.767712                0.627741             0       55.0
# 19996          958.395633                0.334418             0       54.0
# 19997          945.427454                0.357227             0       45.0
# 19998          411.168284                0.408678             0       59.0
# 19999         1049.830407                0.298006             0       59.0
#
# [20000 rows x 35 columns]

# %% [markdown]
# Defining Features and target

# %%
X = copy.drop(columns = ['RiskScore'])
Y = copy["RiskScore"]

# %% [markdown]
# Visualizing Outliers

# %%
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(20, 15))
axes = axes.flatten()

for i, column in enumerate(copy.columns[:]):
    sns.boxplot(data=copy, y=column, ax=axes[i], color='red')
    axes[i].set_title(column, fontsize=10)
    axes[i].set_ylabel('')
    axes[i].tick_params(axis='y', labelsize=8)



plt.tight_layout()
plt.show()

# %% [markdown]
# Handling Outliers by Robust Scaling

# %%
robust = RobustScaler()
scaledX = robust.fit_transform(X)
scaledY = robust.fit_transform(Y.values.reshape(-1,1))

# %% [markdown]
# After Outliers Handling

# %%
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(20, 15))
axes = axes.flatten()

for i, column in enumerate(copy.columns[:]):
    sns.boxplot(data=copy, y=column, ax=axes[i], color='red')
    axes[i].set_title(column, fontsize=10)
    axes[i].set_ylabel('')
    axes[i].tick_params(axis='y', labelsize=8)



plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualization

# %%
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(20, 15))
axes = axes.flatten()

for i, column in enumerate(X.columns[:]):
    sns.histplot(data=X, y=column, ax=axes[i], color='red')
    axes[i].set_title(column, fontsize=10)
    axes[i].set_ylabel('')
    axes[i].tick_params(axis='y', labelsize=8)



plt.tight_layout()
plt.show()

# %% [markdown]
# #Correlations Identify

# %%
corrMatrix = copy.corr()
strongPositveCorr = []
strongPositveCorrWithOneColumn = {}
for i in corrMatrix.columns:
    for j in corrMatrix.columns:
        if i==j:
            continue
        if(corrMatrix.loc[i, j]>=0.8):
            strongPositveCorr.append(j)
        print(f"Correlation between {i} and {j}: {corrMatrix.loc[i, j]:.2f}")
    strongPositveCorrWithOneColumn[i] = strongPositveCorr
    strongPositveCorr = []
        # We can do the same thing for moderate and weak corr
print(strongPositveCorrWithOneColumn)
# Out:
# Correlation between Age and AnnualIncome: 0.14
# Correlation between Age and CreditScore: 0.32
# Correlation between Age and EmploymentStatus: 0.00
# Correlation between Age and EducationLevel: -0.00
# Correlation between Age and Experience: 0.98
# Correlation between Age and LoanAmount: -0.01
# Correlation between Age and LoanDuration: -0.01
# Correlation between Age and MaritalStatus: -0.01
# Correlation between Age and NumberOfDependents: -0.00
# Correlation between Age and HomeOwnershipStatus: -0.00
# Correlation between Age and MonthlyDebtPayments: 0.02
# Correlation between Age and CreditCardUtilizationRate: -0.00
# Correlation between Age and NumberOfOpenCreditLines: -0.00
# Correlation between Age and NumberOfCreditInquiries: -0.00
# Correlation between Age and DebtToIncomeRatio: 0.00
# Correlation between Age and BankruptcyHistory: 0.01
# Correlation between Age and LoanPurpose: -0.01
# Correlation between Age and PreviousLoanDefaults: -0.00
# Correlation between Age and PaymentHistory: -0.00
# Correlation between Age and LengthOfCreditHistory: -0.00
# Correlation between Age and SavingsAccountBalance: 0.00
# Correlation between Age and CheckingAccountBalance: 0.01
# Correlation between Age and TotalAssets: 0.01
# Correlation between Age and TotalLiabilities: -0.00
# Correlation between Age and MonthlyIncome: 0.14
# Correlation between Age and UtilityBillsPaymentHistory: -0.01
# Correlation between Age and JobTenure: -0.00
# Correlation between Age and NetWorth: 0.01
# Correlation between Age and BaseInterestRate: -0.24
# Correlation between Age and InterestRate: -0.20
# Correlation between Age and MonthlyLoanPayment: -0.02
# Correlation between Age and TotalDebtToIncomeRatio: -0.11
# Correlation between Age and LoanApproved: 0.14
# Correlation between Age and RiskScore: -0.16
# Correlation between AnnualIncome and Age: 0.14
# Correlation between AnnualIncome and CreditScore: 0.10
# Correlation between AnnualIncome and EmploymentStatus: 0.01
# Correlation between AnnualIncome and EducationLevel: 0.00
# Correlation between AnnualIncome and Experience: 0.15
# Correlation between AnnualIncome and LoanAmount: -0.00
# Correlation between AnnualIncome and LoanDuration: 0.00
# Correlation between AnnualIncome and MaritalStatus: -0.01
# Correlation between AnnualIncome and NumberOfDependents: -0.00
# Correlation between AnnualIncome and HomeOwnershipStatus: 0.01
# Correlation between AnnualIncome and MonthlyDebtPayments: -0.00
# Correlation between AnnualIncome and CreditCardUtilizationRate: -0.01
# Correlation between AnnualIncome and NumberOfOpenCreditLines: -0.01
# Correlation between AnnualIncome and NumberOfCreditInquiries: -0.01
# Correlation between AnnualIncome and DebtToIncomeRatio: 0.00
# Correlation between AnnualIncome and BankruptcyHistory: 0.00
# Correlation between AnnualIncome and LoanPurpose: -0.01
# Correlation between AnnualIncome and PreviousLoanDefaults: 0.00
# Correlation between AnnualIncome and PaymentHistory: 0.00
# Correlation between AnnualIncome and LengthOfCreditHistory: -0.01
# Correlation between AnnualIncome and SavingsAccountBalance: -0.00
# Correlation between AnnualIncome and CheckingAccountBalance: 0.01
# Correlation between AnnualIncome and TotalAssets: -0.01
# Correlation between AnnualIncome and TotalLiabilities: -0.00
# Correlation between AnnualIncome and MonthlyIncome: 0.99
# Correlation between AnnualIncome and UtilityBillsPaymentHistory: -0.01
# Correlation between AnnualIncome and JobTenure: -0.00
# Correlation between AnnualIncome and NetWorth: -0.00
# Correlation between AnnualIncome and BaseInterestRate: -0.07
# Correlation between AnnualIncome and InterestRate: -0.06
# Correlation between AnnualIncome and MonthlyLoanPayment: -0.00
# Correlation between AnnualIncome and TotalDebtToIncomeRatio: -0.53
# Correlation between AnnualIncome and LoanApproved: 0.60
# Correlation between AnnualIncome and RiskScore: -0.48
# Correlation between CreditScore and Age: 0.32
# Correlation between CreditScore and AnnualIncome: 0.10
# Correlation between CreditScore and EmploymentStatus: 0.02
# Correlation between CreditScore and EducationLevel: 0.01
# Correlation between CreditScore and Experience: 0.33
# Correlation between CreditScore and LoanAmount: -0.01
# Correlation between CreditScore and LoanDuration: -0.00
# Correlation between CreditScore and MaritalStatus: -0.00
# Correlation between CreditScore and NumberOfDependents: -0.01
# Correlation between CreditScore and HomeOwnershipStatus: 0.01
# Correlation between CreditScore and MonthlyDebtPayments: 0.01
# Correlation between CreditScore and CreditCardUtilizationRate: -0.01
# Correlation between CreditScore and NumberOfOpenCreditLines: -0.01
# Correlation between CreditScore and NumberOfCreditInquiries: -0.00
# Correlation between CreditScore and DebtToIncomeRatio: 0.00
# Correlation between CreditScore and BankruptcyHistory: 0.01
# Correlation between CreditScore and LoanPurpose: -0.01
# Correlation between CreditScore and PreviousLoanDefaults: -0.01
# Correlation between CreditScore and PaymentHistory: 0.00
# Correlation between CreditScore and LengthOfCreditHistory: 0.01
# Correlation between CreditScore and SavingsAccountBalance: -0.01
# Correlation between CreditScore and CheckingAccountBalance: 0.01
# Correlation between CreditScore and TotalAssets: 0.00
# Correlation between CreditScore and TotalLiabilities: -0.01
# Correlation between CreditScore and MonthlyIncome: 0.10
# Correlation between CreditScore and UtilityBillsPaymentHistory: -0.01
# Correlation between CreditScore and JobTenure: 0.01
# Correlation between CreditScore and NetWorth: 0.00
# Correlation between CreditScore and BaseInterestRate: -0.72
# Correlation between CreditScore and InterestRate: -0.60
# Correlation between CreditScore and MonthlyLoanPayment: -0.06
# Correlation between CreditScore and TotalDebtToIncomeRatio: -0.12
# Correlation between CreditScore and LoanApproved: 0.14
# Correlation between CreditScore and RiskScore: -0.24
# Correlation between EmploymentStatus and Age: 0.00
# Correlation between EmploymentStatus and AnnualIncome: 0.01
# Correlation between EmploymentStatus and CreditScore: 0.02
# Correlation between EmploymentStatus and EducationLevel: 0.01
# Correlation between EmploymentStatus and Experience: 0.00
# Correlation between EmploymentStatus and LoanAmount: 0.01
# Correlation between EmploymentStatus and LoanDuration: -0.00
# Correlation between EmploymentStatus and MaritalStatus: -0.00
# Correlation between EmploymentStatus and NumberOfDependents: -0.00
# Correlation between EmploymentStatus and HomeOwnershipStatus: 0.00
# Correlation between EmploymentStatus and MonthlyDebtPayments: 0.00
# Correlation between EmploymentStatus and CreditCardUtilizationRate: 0.02
# Correlation between EmploymentStatus and NumberOfOpenCreditLines: 0.01
# Correlation between EmploymentStatus and NumberOfCreditInquiries: 0.00
# Correlation between EmploymentStatus and DebtToIncomeRatio: 0.00
# Correlation between EmploymentStatus and BankruptcyHistory: -0.00
# Correlation between EmploymentStatus and LoanPurpose: 0.00
# Correlation between EmploymentStatus and PreviousLoanDefaults: -0.01
# Correlation between EmploymentStatus and PaymentHistory: 0.01
# Correlation between EmploymentStatus and LengthOfCreditHistory: -0.00
# Correlation between EmploymentStatus and SavingsAccountBalance: 0.01
# Correlation between EmploymentStatus and CheckingAccountBalance: -0.00
# Correlation between EmploymentStatus and TotalAssets: -0.01
# Correlation between EmploymentStatus and TotalLiabilities: 0.00
# Correlation between EmploymentStatus and MonthlyIncome: 0.01
# Correlation between EmploymentStatus and UtilityBillsPaymentHistory: 0.00
# Correlation between EmploymentStatus and JobTenure: 0.00
# Correlation between EmploymentStatus and NetWorth: -0.01
# Correlation between EmploymentStatus and BaseInterestRate: -0.01
# Correlation between EmploymentStatus and InterestRate: -0.01
# Correlation between EmploymentStatus and MonthlyLoanPayment: 0.01
# Correlation between EmploymentStatus and TotalDebtToIncomeRatio: -0.01
# Correlation between EmploymentStatus and LoanApproved: -0.02
# Correlation between EmploymentStatus and RiskScore: 0.13
# Correlation between EducationLevel and Age: -0.00
# Correlation between EducationLevel and AnnualIncome: 0.00
# Correlation between EducationLevel and CreditScore: 0.01
# Correlation between EducationLevel and EmploymentStatus: 0.01
# Correlation between EducationLevel and Experience: -0.00
# Correlation between EducationLevel and LoanAmount: 0.00
# Correlation between EducationLevel and LoanDuration: -0.00
# Correlation between EducationLevel and MaritalStatus: 0.00
# Correlation between EducationLevel and NumberOfDependents: -0.01
# Correlation between EducationLevel and HomeOwnershipStatus: 0.00
# Correlation between EducationLevel and MonthlyDebtPayments: -0.00
# Correlation between EducationLevel and CreditCardUtilizationRate: 0.01
# Correlation between EducationLevel and NumberOfOpenCreditLines: 0.01
# Correlation between EducationLevel and NumberOfCreditInquiries: 0.01
# Correlation between EducationLevel and DebtToIncomeRatio: 0.00
# Correlation between EducationLevel and BankruptcyHistory: 0.00
# Correlation between EducationLevel and LoanPurpose: 0.01
# Correlation between EducationLevel and PreviousLoanDefaults: -0.00
# Correlation between EducationLevel and PaymentHistory: -0.00
# Correlation between EducationLevel and LengthOfCreditHistory: 0.00
# Correlation between EducationLevel and SavingsAccountBalance: -0.00
# Correlation between EducationLevel and CheckingAccountBalance: 0.01
# Correlation between EducationLevel and TotalAssets: 0.01
# Correlation between EducationLevel and TotalLiabilities: 0.01
# Correlation between EducationLevel and MonthlyIncome: 0.00
# Correlation between EducationLevel and UtilityBillsPaymentHistory: 0.00
# Correlation between EducationLevel and JobTenure: 0.00
# Correlation between EducationLevel and NetWorth: 0.01
# Correlation between EducationLevel and BaseInterestRate: -0.01
# Correlation between EducationLevel and InterestRate: -0.00
# Correlation between EducationLevel and MonthlyLoanPayment: 0.00
# Correlation between EducationLevel and TotalDebtToIncomeRatio: 0.00
# Correlation between EducationLevel and LoanApproved: 0.02
# Correlation between EducationLevel and RiskScore: -0.02
# Correlation between Experience and Age: 0.98
# Correlation between Experience and AnnualIncome: 0.15
# Correlation between Experience and CreditScore: 0.33
# Correlation between Experience and EmploymentStatus: 0.00
# Correlation between Experience and EducationLevel: -0.00
# Correlation between Experience and LoanAmount: -0.01
# Correlation between Experience and LoanDuration: -0.01
# Correlation between Experience and MaritalStatus: -0.00
# Correlation between Experience and NumberOfDependents: 0.00
# Correlation between Experience and HomeOwnershipStatus: -0.00
# Correlation between Experience and MonthlyDebtPayments: 0.02
# Correlation between Experience and CreditCardUtilizationRate: -0.00
# Correlation between Experience and NumberOfOpenCreditLines: -0.00
# Correlation between Experience and NumberOfCreditInquiries: -0.00
# Correlation between Experience and DebtToIncomeRatio: 0.00
# Correlation between Experience and BankruptcyHistory: 0.01
# Correlation between Experience and LoanPurpose: -0.01
# Correlation between Experience and PreviousLoanDefaults: -0.00
# Correlation between Experience and PaymentHistory: -0.00
# Correlation between Experience and LengthOfCreditHistory: -0.00
# Correlation between Experience and SavingsAccountBalance: 0.01
# Correlation between Experience and CheckingAccountBalance: 0.01
# Correlation between Experience and TotalAssets: 0.01
# Correlation between Experience and TotalLiabilities: -0.00
# Correlation between Experience and MonthlyIncome: 0.15
# Correlation between Experience and UtilityBillsPaymentHistory: -0.01
# Correlation between Experience and JobTenure: -0.00
# Correlation between Experience and NetWorth: 0.02
# Correlation between Experience and BaseInterestRate: -0.24
# Correlation between Experience and InterestRate: -0.21
# Correlation between Experience and MonthlyLoanPayment: -0.02
# Correlation between Experience and TotalDebtToIncomeRatio: -0.11
# Correlation between Experience and LoanApproved: 0.14
# Correlation between Experience and RiskScore: -0.17
# Correlation between LoanAmount and Age: -0.01
# Correlation between LoanAmount and AnnualIncome: -0.00
# Correlation between LoanAmount and CreditScore: -0.01
# Correlation between LoanAmount and EmploymentStatus: 0.01
# Correlation between LoanAmount and EducationLevel: 0.00
# Correlation between LoanAmount and Experience: -0.01
# Correlation between LoanAmount and LoanDuration: -0.00
# Correlation between LoanAmount and MaritalStatus: -0.00
# Correlation between LoanAmount and NumberOfDependents: -0.01
# Correlation between LoanAmount and HomeOwnershipStatus: 0.01
# Correlation between LoanAmount and MonthlyDebtPayments: 0.02
# Correlation between LoanAmount and CreditCardUtilizationRate: 0.00
# Correlation between LoanAmount and NumberOfOpenCreditLines: 0.00
# Correlation between LoanAmount and NumberOfCreditInquiries: -0.01
# Correlation between LoanAmount and DebtToIncomeRatio: -0.01
# Correlation between LoanAmount and BankruptcyHistory: 0.00
# Correlation between LoanAmount and LoanPurpose: -0.00
# Correlation between LoanAmount and PreviousLoanDefaults: -0.00
# Correlation between LoanAmount and PaymentHistory: -0.00
# Correlation between LoanAmount and LengthOfCreditHistory: 0.00
# Correlation between LoanAmount and SavingsAccountBalance: 0.00
# Correlation between LoanAmount and CheckingAccountBalance: 0.01
# Correlation between LoanAmount and TotalAssets: -0.00
# Correlation between LoanAmount and TotalLiabilities: 0.00
# Correlation between LoanAmount and MonthlyIncome: -0.01
# Correlation between LoanAmount and UtilityBillsPaymentHistory: -0.01
# Correlation between LoanAmount and JobTenure: 0.01
# Correlation between LoanAmount and NetWorth: -0.00
# Correlation between LoanAmount and BaseInterestRate: 0.39
# Correlation between LoanAmount and InterestRate: 0.32
# Correlation between LoanAmount and MonthlyLoanPayment: 0.78
# Correlation between LoanAmount and TotalDebtToIncomeRatio: 0.46
# Correlation between LoanAmount and LoanApproved: -0.24
# Correlation between LoanAmount and RiskScore: 0.14
# Correlation between LoanDuration and Age: -0.01
# Correlation between LoanDuration and AnnualIncome: 0.00
# Correlation between LoanDuration and CreditScore: -0.00
# Correlation between LoanDuration and EmploymentStatus: -0.00
# Correlation between LoanDuration and EducationLevel: -0.00
# Correlation between LoanDuration and Experience: -0.01
# Correlation between LoanDuration and LoanAmount: -0.00
# Correlation between LoanDuration and MaritalStatus: 0.00
# Correlation between LoanDuration and NumberOfDependents: -0.00
# Correlation between LoanDuration and HomeOwnershipStatus: -0.01
# Correlation between LoanDuration and MonthlyDebtPayments: 0.00
# Correlation between LoanDuration and CreditCardUtilizationRate: -0.01
# Correlation between LoanDuration and NumberOfOpenCreditLines: 0.00
# Correlation between LoanDuration and NumberOfCreditInquiries: 0.00
# Correlation between LoanDuration and DebtToIncomeRatio: 0.00
# Correlation between LoanDuration and BankruptcyHistory: -0.00
# Correlation between LoanDuration and LoanPurpose: -0.01
# Correlation between LoanDuration and PreviousLoanDefaults: 0.02
# Correlation between LoanDuration and PaymentHistory: 0.00
# Correlation between LoanDuration and LengthOfCreditHistory: 0.01
# Correlation between LoanDuration and SavingsAccountBalance: 0.00
# Correlation between LoanDuration and CheckingAccountBalance: -0.00
# Correlation between LoanDuration and TotalAssets: -0.01
# Correlation between LoanDuration and TotalLiabilities: 0.00
# Correlation between LoanDuration and MonthlyIncome: 0.00
# Correlation between LoanDuration and UtilityBillsPaymentHistory: -0.01
# Correlation between LoanDuration and JobTenure: 0.00
# Correlation between LoanDuration and NetWorth: -0.01
# Correlation between LoanDuration and BaseInterestRate: 0.58
# Correlation between LoanDuration and InterestRate: 0.49
# Correlation between LoanDuration and MonthlyLoanPayment: -0.39
# Correlation between LoanDuration and TotalDebtToIncomeRatio: -0.21
# Correlation between LoanDuration and LoanApproved: -0.09
# Correlation between LoanDuration and RiskScore: 0.05
# Correlation between MaritalStatus and Age: -0.01
# Correlation between MaritalStatus and AnnualIncome: -0.01
# Correlation between MaritalStatus and CreditScore: -0.00
# Correlation between MaritalStatus and EmploymentStatus: -0.00
# Correlation between MaritalStatus and EducationLevel: 0.00
# Correlation between MaritalStatus and Experience: -0.00
# Correlation between MaritalStatus and LoanAmount: -0.00
# Correlation between MaritalStatus and LoanDuration: 0.00
# Correlation between MaritalStatus and NumberOfDependents: 0.00
# Correlation between MaritalStatus and HomeOwnershipStatus: 0.01
# Correlation between MaritalStatus and MonthlyDebtPayments: 0.01
# Correlation between MaritalStatus and CreditCardUtilizationRate: 0.00
# Correlation between MaritalStatus and NumberOfOpenCreditLines: 0.01
# Correlation between MaritalStatus and NumberOfCreditInquiries: 0.01
# Correlation between MaritalStatus and DebtToIncomeRatio: 0.01
# Correlation between MaritalStatus and BankruptcyHistory: 0.02
# Correlation between MaritalStatus and LoanPurpose: 0.00
# Correlation between MaritalStatus and PreviousLoanDefaults: 0.01
# Correlation between MaritalStatus and PaymentHistory: 0.01
# Correlation between MaritalStatus and LengthOfCreditHistory: 0.00
# Correlation between MaritalStatus and SavingsAccountBalance: -0.01
# Correlation between MaritalStatus and CheckingAccountBalance: -0.01
# Correlation between MaritalStatus and TotalAssets: -0.00
# Correlation between MaritalStatus and TotalLiabilities: 0.00
# Correlation between MaritalStatus and MonthlyIncome: -0.01
# Correlation between MaritalStatus and UtilityBillsPaymentHistory: 0.00
# Correlation between MaritalStatus and JobTenure: 0.01
# Correlation between MaritalStatus and NetWorth: -0.00
# Correlation between MaritalStatus and BaseInterestRate: 0.00
# Correlation between MaritalStatus and InterestRate: 0.00
# Correlation between MaritalStatus and MonthlyLoanPayment: 0.00
# Correlation between MaritalStatus and TotalDebtToIncomeRatio: 0.01
# Correlation between MaritalStatus and LoanApproved: -0.01
# Correlation between MaritalStatus and RiskScore: 0.02
# Correlation between NumberOfDependents and Age: -0.00
# Correlation between NumberOfDependents and AnnualIncome: -0.00
# Correlation between NumberOfDependents and CreditScore: -0.01
# Correlation between NumberOfDependents and EmploymentStatus: -0.00
# Correlation between NumberOfDependents and EducationLevel: -0.01
# Correlation between NumberOfDependents and Experience: 0.00
# Correlation between NumberOfDependents and LoanAmount: -0.01
# Correlation between NumberOfDependents and LoanDuration: -0.00
# Correlation between NumberOfDependents and MaritalStatus: 0.00
# Correlation between NumberOfDependents and HomeOwnershipStatus: -0.00
# Correlation between NumberOfDependents and MonthlyDebtPayments: -0.00
# Correlation between NumberOfDependents and CreditCardUtilizationRate: 0.01
# Correlation between NumberOfDependents and NumberOfOpenCreditLines: 0.01
# Correlation between NumberOfDependents and NumberOfCreditInquiries: -0.00
# Correlation between NumberOfDependents and DebtToIncomeRatio: -0.01
# Correlation between NumberOfDependents and BankruptcyHistory: -0.00
# Correlation between NumberOfDependents and LoanPurpose: 0.01
# Correlation between NumberOfDependents and PreviousLoanDefaults: 0.01
# Correlation between NumberOfDependents and PaymentHistory: 0.00
# Correlation between NumberOfDependents and LengthOfCreditHistory: 0.00
# Correlation between NumberOfDependents and SavingsAccountBalance: -0.00
# Correlation between NumberOfDependents and CheckingAccountBalance: 0.00
# Correlation between NumberOfDependents and TotalAssets: -0.01
# Correlation between NumberOfDependents and TotalLiabilities: 0.01
# Correlation between NumberOfDependents and MonthlyIncome: -0.00
# Correlation between NumberOfDependents and UtilityBillsPaymentHistory: 0.01
# Correlation between NumberOfDependents and JobTenure: 0.01
# Correlation between NumberOfDependents and NetWorth: -0.01
# Correlation between NumberOfDependents and BaseInterestRate: 0.01
# Correlation between NumberOfDependents and InterestRate: 0.01
# Correlation between NumberOfDependents and MonthlyLoanPayment: -0.00
# Correlation between NumberOfDependents and TotalDebtToIncomeRatio: -0.00
# Correlation between NumberOfDependents and LoanApproved: 0.00
# Correlation between NumberOfDependents and RiskScore: 0.00
# Correlation between HomeOwnershipStatus and Age: -0.00
# Correlation between HomeOwnershipStatus and AnnualIncome: 0.01
# Correlation between HomeOwnershipStatus and CreditScore: 0.01
# Correlation between HomeOwnershipStatus and EmploymentStatus: 0.00
# Correlation between HomeOwnershipStatus and EducationLevel: 0.00
# Correlation between HomeOwnershipStatus and Experience: -0.00
# Correlation between HomeOwnershipStatus and LoanAmount: 0.01
# Correlation between HomeOwnershipStatus and LoanDuration: -0.01
# Correlation between HomeOwnershipStatus and MaritalStatus: 0.01
# Correlation between HomeOwnershipStatus and NumberOfDependents: -0.00
# Correlation between HomeOwnershipStatus and MonthlyDebtPayments: -0.00
# Correlation between HomeOwnershipStatus and CreditCardUtilizationRate: -0.01
# Correlation between HomeOwnershipStatus and NumberOfOpenCreditLines: -0.00
# Correlation between HomeOwnershipStatus and NumberOfCreditInquiries: 0.01
# Correlation between HomeOwnershipStatus and DebtToIncomeRatio: -0.00
# Correlation between HomeOwnershipStatus and BankruptcyHistory: -0.00
# Correlation between HomeOwnershipStatus and LoanPurpose: -0.01
# Correlation between HomeOwnershipStatus and PreviousLoanDefaults: 0.01
# Correlation between HomeOwnershipStatus and PaymentHistory: 0.00
# Correlation between HomeOwnershipStatus and LengthOfCreditHistory: 0.00
# Correlation between HomeOwnershipStatus and SavingsAccountBalance: -0.01
# Correlation between HomeOwnershipStatus and CheckingAccountBalance: 0.01
# Correlation between HomeOwnershipStatus and TotalAssets: 0.00
# Correlation between HomeOwnershipStatus and TotalLiabilities: -0.01
# Correlation between HomeOwnershipStatus and MonthlyIncome: 0.01
# Correlation between HomeOwnershipStatus and UtilityBillsPaymentHistory: 0.00
# Correlation between HomeOwnershipStatus and JobTenure: 0.01
# Correlation between HomeOwnershipStatus and NetWorth: 0.01
# Correlation between HomeOwnershipStatus and BaseInterestRate: -0.01
# Correlation between HomeOwnershipStatus and InterestRate: -0.00
# Correlation between HomeOwnershipStatus and MonthlyLoanPayment: 0.01
# Correlation between HomeOwnershipStatus and TotalDebtToIncomeRatio: 0.00
# Correlation between HomeOwnershipStatus and LoanApproved: -0.02
# Correlation between HomeOwnershipStatus and RiskScore: 0.00
# Correlation between MonthlyDebtPayments and Age: 0.02
# Correlation between MonthlyDebtPayments and AnnualIncome: -0.00
# Correlation between MonthlyDebtPayments and CreditScore: 0.01
# Correlation between MonthlyDebtPayments and EmploymentStatus: 0.00
# Correlation between MonthlyDebtPayments and EducationLevel: -0.00
# Correlation between MonthlyDebtPayments and Experience: 0.02
# Correlation between MonthlyDebtPayments and LoanAmount: 0.02
# Correlation between MonthlyDebtPayments and LoanDuration: 0.00
# Correlation between MonthlyDebtPayments and MaritalStatus: 0.01
# Correlation between MonthlyDebtPayments and NumberOfDependents: -0.00
# Correlation between MonthlyDebtPayments and HomeOwnershipStatus: -0.00
# Correlation between MonthlyDebtPayments and CreditCardUtilizationRate: 0.01
# Correlation between MonthlyDebtPayments and NumberOfOpenCreditLines: 0.01
# Correlation between MonthlyDebtPayments and NumberOfCreditInquiries: 0.01
# Correlation between MonthlyDebtPayments and DebtToIncomeRatio: 0.00
# Correlation between MonthlyDebtPayments and BankruptcyHistory: -0.01
# Correlation between MonthlyDebtPayments and LoanPurpose: -0.00
# Correlation between MonthlyDebtPayments and PreviousLoanDefaults: 0.00
# Correlation between MonthlyDebtPayments and PaymentHistory: -0.00
# Correlation between MonthlyDebtPayments and LengthOfCreditHistory: -0.00
# Correlation between MonthlyDebtPayments and SavingsAccountBalance: -0.00
# Correlation between MonthlyDebtPayments and CheckingAccountBalance: 0.00
# Correlation between MonthlyDebtPayments and TotalAssets: 0.00
# Correlation between MonthlyDebtPayments and TotalLiabilities: -0.00
# Correlation between MonthlyDebtPayments and MonthlyIncome: -0.00
# Correlation between MonthlyDebtPayments and UtilityBillsPaymentHistory: 0.00
# Correlation between MonthlyDebtPayments and JobTenure: 0.01
# Correlation between MonthlyDebtPayments and NetWorth: 0.00
# Correlation between MonthlyDebtPayments and BaseInterestRate: 0.00
# Correlation between MonthlyDebtPayments and InterestRate: 0.00
# Correlation between MonthlyDebtPayments and MonthlyLoanPayment: 0.02
# Correlation between MonthlyDebtPayments and TotalDebtToIncomeRatio: 0.22
# Correlation between MonthlyDebtPayments and LoanApproved: -0.07
# Correlation between MonthlyDebtPayments and RiskScore: 0.04
# Correlation between CreditCardUtilizationRate and Age: -0.00
# Correlation between CreditCardUtilizationRate and AnnualIncome: -0.01
# Correlation between CreditCardUtilizationRate and CreditScore: -0.01
# Correlation between CreditCardUtilizationRate and EmploymentStatus: 0.02
# Correlation between CreditCardUtilizationRate and EducationLevel: 0.01
# Correlation between CreditCardUtilizationRate and Experience: -0.00
# Correlation between CreditCardUtilizationRate and LoanAmount: 0.00
# Correlation between CreditCardUtilizationRate and LoanDuration: -0.01
# Correlation between CreditCardUtilizationRate and MaritalStatus: 0.00
# Correlation between CreditCardUtilizationRate and NumberOfDependents: 0.01
# Correlation between CreditCardUtilizationRate and HomeOwnershipStatus: -0.01
# Correlation between CreditCardUtilizationRate and MonthlyDebtPayments: 0.01
# Correlation between CreditCardUtilizationRate and NumberOfOpenCreditLines: 0.00
# Correlation between CreditCardUtilizationRate and NumberOfCreditInquiries: 0.00
# Correlation between CreditCardUtilizationRate and DebtToIncomeRatio: 0.00
# Correlation between CreditCardUtilizationRate and BankruptcyHistory: 0.01
# Correlation between CreditCardUtilizationRate and LoanPurpose: 0.00
# Correlation between CreditCardUtilizationRate and PreviousLoanDefaults: -0.00
# Correlation between CreditCardUtilizationRate and PaymentHistory: 0.00
# Correlation between CreditCardUtilizationRate and LengthOfCreditHistory: 0.01
# Correlation between CreditCardUtilizationRate and SavingsAccountBalance: 0.00
# Correlation between CreditCardUtilizationRate and CheckingAccountBalance: -0.00
# Correlation between CreditCardUtilizationRate and TotalAssets: -0.01
# Correlation between CreditCardUtilizationRate and TotalLiabilities: -0.01
# Correlation between CreditCardUtilizationRate and MonthlyIncome: -0.01
# Correlation between CreditCardUtilizationRate and UtilityBillsPaymentHistory: 0.01
# Correlation between CreditCardUtilizationRate and JobTenure: -0.01
# Correlation between CreditCardUtilizationRate and NetWorth: -0.00
# Correlation between CreditCardUtilizationRate and BaseInterestRate: 0.00
# Correlation between CreditCardUtilizationRate and InterestRate: 0.00
# Correlation between CreditCardUtilizationRate and MonthlyLoanPayment: 0.00
# Correlation between CreditCardUtilizationRate and TotalDebtToIncomeRatio: 0.01
# Correlation between CreditCardUtilizationRate and LoanApproved: -0.01
# Correlation between CreditCardUtilizationRate and RiskScore: 0.11
# Correlation between NumberOfOpenCreditLines and Age: -0.00
# Correlation between NumberOfOpenCreditLines and AnnualIncome: -0.01
# Correlation between NumberOfOpenCreditLines and CreditScore: -0.01
# Correlation between NumberOfOpenCreditLines and EmploymentStatus: 0.01
# Correlation between NumberOfOpenCreditLines and EducationLevel: 0.01
# Correlation between NumberOfOpenCreditLines and Experience: -0.00
# Correlation between NumberOfOpenCreditLines and LoanAmount: 0.00
# Correlation between NumberOfOpenCreditLines and LoanDuration: 0.00
# Correlation between NumberOfOpenCreditLines and MaritalStatus: 0.01
# Correlation between NumberOfOpenCreditLines and NumberOfDependents: 0.01
# Correlation between NumberOfOpenCreditLines and HomeOwnershipStatus: -0.00
# Correlation between NumberOfOpenCreditLines and MonthlyDebtPayments: 0.01
# Correlation between NumberOfOpenCreditLines and CreditCardUtilizationRate: 0.00
# Correlation between NumberOfOpenCreditLines and NumberOfCreditInquiries: 0.00
# Correlation between NumberOfOpenCreditLines and DebtToIncomeRatio: 0.00
# Correlation between NumberOfOpenCreditLines and BankruptcyHistory: -0.00
# Correlation between NumberOfOpenCreditLines and LoanPurpose: -0.00
# Correlation between NumberOfOpenCreditLines and PreviousLoanDefaults: 0.01
# Correlation between NumberOfOpenCreditLines and PaymentHistory: 0.00
# Correlation between NumberOfOpenCreditLines and LengthOfCreditHistory: 0.00
# Correlation between NumberOfOpenCreditLines and SavingsAccountBalance: 0.01
# Correlation between NumberOfOpenCreditLines and CheckingAccountBalance: -0.01
# Correlation between NumberOfOpenCreditLines and TotalAssets: -0.00
# Correlation between NumberOfOpenCreditLines and TotalLiabilities: -0.01
# Correlation between NumberOfOpenCreditLines and MonthlyIncome: -0.01
# Correlation between NumberOfOpenCreditLines and UtilityBillsPaymentHistory: -0.01
# Correlation between NumberOfOpenCreditLines and JobTenure: 0.01
# Correlation between NumberOfOpenCreditLines and NetWorth: -0.00
# Correlation between NumberOfOpenCreditLines and BaseInterestRate: 0.01
# Correlation between NumberOfOpenCreditLines and InterestRate: 0.01
# Correlation between NumberOfOpenCreditLines and MonthlyLoanPayment: -0.01
# Correlation between NumberOfOpenCreditLines and TotalDebtToIncomeRatio: 0.00
# Correlation between NumberOfOpenCreditLines and LoanApproved: -0.00
# Correlation between NumberOfOpenCreditLines and RiskScore: 0.01
# Correlation between NumberOfCreditInquiries and Age: -0.00
# Correlation between NumberOfCreditInquiries and AnnualIncome: -0.01
# Correlation between NumberOfCreditInquiries and CreditScore: -0.00
# Correlation between NumberOfCreditInquiries and EmploymentStatus: 0.00
# Correlation between NumberOfCreditInquiries and EducationLevel: 0.01
# Correlation between NumberOfCreditInquiries and Experience: -0.00
# Correlation between NumberOfCreditInquiries and LoanAmount: -0.01
# Correlation between NumberOfCreditInquiries and LoanDuration: 0.00
# Correlation between NumberOfCreditInquiries and MaritalStatus: 0.01
# Correlation between NumberOfCreditInquiries and NumberOfDependents: -0.00
# Correlation between NumberOfCreditInquiries and HomeOwnershipStatus: 0.01
# Correlation between NumberOfCreditInquiries and MonthlyDebtPayments: 0.01
# Correlation between NumberOfCreditInquiries and CreditCardUtilizationRate: 0.00
# Correlation between NumberOfCreditInquiries and NumberOfOpenCreditLines: 0.00
# Correlation between NumberOfCreditInquiries and DebtToIncomeRatio: 0.01
# Correlation between NumberOfCreditInquiries and BankruptcyHistory: -0.01
# Correlation between NumberOfCreditInquiries and LoanPurpose: 0.00
# Correlation between NumberOfCreditInquiries and PreviousLoanDefaults: -0.01
# Correlation between NumberOfCreditInquiries and PaymentHistory: -0.00
# Correlation between NumberOfCreditInquiries and LengthOfCreditHistory: -0.00
# Correlation between NumberOfCreditInquiries and SavingsAccountBalance: -0.00
# Correlation between NumberOfCreditInquiries and CheckingAccountBalance: -0.00
# Correlation between NumberOfCreditInquiries and TotalAssets: 0.01
# Correlation between NumberOfCreditInquiries and TotalLiabilities: 0.00
# Correlation between NumberOfCreditInquiries and MonthlyIncome: -0.01
# Correlation between NumberOfCreditInquiries and UtilityBillsPaymentHistory: 0.01
# Correlation between NumberOfCreditInquiries and JobTenure: 0.00
# Correlation between NumberOfCreditInquiries and NetWorth: 0.00
# Correlation between NumberOfCreditInquiries and BaseInterestRate: -0.00
# Correlation between NumberOfCreditInquiries and InterestRate: -0.01
# Correlation between NumberOfCreditInquiries and MonthlyLoanPayment: -0.00
# Correlation between NumberOfCreditInquiries and TotalDebtToIncomeRatio: -0.00
# Correlation between NumberOfCreditInquiries and LoanApproved: -0.01
# Correlation between NumberOfCreditInquiries and RiskScore: 0.00
# Correlation between DebtToIncomeRatio and Age: 0.00
# Correlation between DebtToIncomeRatio and AnnualIncome: 0.00
# Correlation between DebtToIncomeRatio and CreditScore: 0.00
# Correlation between DebtToIncomeRatio and EmploymentStatus: 0.00
# Correlation between DebtToIncomeRatio and EducationLevel: 0.00
# Correlation between DebtToIncomeRatio and Experience: 0.00
# Correlation between DebtToIncomeRatio and LoanAmount: -0.01
# Correlation between DebtToIncomeRatio and LoanDuration: 0.00
# Correlation between DebtToIncomeRatio and MaritalStatus: 0.01
# Correlation between DebtToIncomeRatio and NumberOfDependents: -0.01
# Correlation between DebtToIncomeRatio and HomeOwnershipStatus: -0.00
# Correlation between DebtToIncomeRatio and MonthlyDebtPayments: 0.00
# Correlation between DebtToIncomeRatio and CreditCardUtilizationRate: 0.00
# Correlation between DebtToIncomeRatio and NumberOfOpenCreditLines: 0.00
# Correlation between DebtToIncomeRatio and NumberOfCreditInquiries: 0.01
# Correlation between DebtToIncomeRatio and BankruptcyHistory: 0.01
# Correlation between DebtToIncomeRatio and LoanPurpose: -0.01
# Correlation between DebtToIncomeRatio and PreviousLoanDefaults: 0.01
# Correlation between DebtToIncomeRatio and PaymentHistory: -0.01
# Correlation between DebtToIncomeRatio and LengthOfCreditHistory: -0.00
# Correlation between DebtToIncomeRatio and SavingsAccountBalance: -0.00
# Correlation between DebtToIncomeRatio and CheckingAccountBalance: 0.00
# Correlation between DebtToIncomeRatio and TotalAssets: -0.01
# Correlation between DebtToIncomeRatio and TotalLiabilities: -0.00
# Correlation between DebtToIncomeRatio and MonthlyIncome: 0.00
# Correlation between DebtToIncomeRatio and UtilityBillsPaymentHistory: -0.01
# Correlation between DebtToIncomeRatio and JobTenure: 0.01
# Correlation between DebtToIncomeRatio and NetWorth: -0.01
# Correlation between DebtToIncomeRatio and BaseInterestRate: -0.00
# Correlation between DebtToIncomeRatio and InterestRate: -0.01
# Correlation between DebtToIncomeRatio and MonthlyLoanPayment: -0.01
# Correlation between DebtToIncomeRatio and TotalDebtToIncomeRatio: -0.01
# Correlation between DebtToIncomeRatio and LoanApproved: 0.00
# Correlation between DebtToIncomeRatio and RiskScore: 0.33
# Correlation between BankruptcyHistory and Age: 0.01
# Correlation between BankruptcyHistory and AnnualIncome: 0.00
# Correlation between BankruptcyHistory and CreditScore: 0.01
# Correlation between BankruptcyHistory and EmploymentStatus: -0.00
# Correlation between BankruptcyHistory and EducationLevel: 0.00
# Correlation between BankruptcyHistory and Experience: 0.01
# Correlation between BankruptcyHistory and LoanAmount: 0.00
# Correlation between BankruptcyHistory and LoanDuration: -0.00
# Correlation between BankruptcyHistory and MaritalStatus: 0.02
# Correlation between BankruptcyHistory and NumberOfDependents: -0.00
# Correlation between BankruptcyHistory and HomeOwnershipStatus: -0.00
# Correlation between BankruptcyHistory and MonthlyDebtPayments: -0.01
# Correlation between BankruptcyHistory and CreditCardUtilizationRate: 0.01
# Correlation between BankruptcyHistory and NumberOfOpenCreditLines: -0.00
# Correlation between BankruptcyHistory and NumberOfCreditInquiries: -0.01
# Correlation between BankruptcyHistory and DebtToIncomeRatio: 0.01
# Correlation between BankruptcyHistory and LoanPurpose: -0.00
# Correlation between BankruptcyHistory and PreviousLoanDefaults: -0.00
# Correlation between BankruptcyHistory and PaymentHistory: 0.01
# Correlation between BankruptcyHistory and LengthOfCreditHistory: 0.01
# Correlation between BankruptcyHistory and SavingsAccountBalance: 0.01
# Correlation between BankruptcyHistory and CheckingAccountBalance: -0.01
# Correlation between BankruptcyHistory and TotalAssets: -0.00
# Correlation between BankruptcyHistory and TotalLiabilities: -0.00
# Correlation between BankruptcyHistory and MonthlyIncome: 0.00
# Correlation between BankruptcyHistory and UtilityBillsPaymentHistory: -0.00
# Correlation between BankruptcyHistory and JobTenure: 0.00
# Correlation between BankruptcyHistory and NetWorth: -0.00
# Correlation between BankruptcyHistory and BaseInterestRate: -0.00
# Correlation between BankruptcyHistory and InterestRate: 0.00
# Correlation between BankruptcyHistory and MonthlyLoanPayment: 0.01
# Correlation between BankruptcyHistory and TotalDebtToIncomeRatio: -0.00
# Correlation between BankruptcyHistory and LoanApproved: -0.07
# Correlation between BankruptcyHistory and RiskScore: 0.38
# Correlation between LoanPurpose and Age: -0.01
# Correlation between LoanPurpose and AnnualIncome: -0.01
# Correlation between LoanPurpose and CreditScore: -0.01
# Correlation between LoanPurpose and EmploymentStatus: 0.00
# Correlation between LoanPurpose and EducationLevel: 0.01
# Correlation between LoanPurpose and Experience: -0.01
# Correlation between LoanPurpose and LoanAmount: -0.00
# Correlation between LoanPurpose and LoanDuration: -0.01
# Correlation between LoanPurpose and MaritalStatus: 0.00
# Correlation between LoanPurpose and NumberOfDependents: 0.01
# Correlation between LoanPurpose and HomeOwnershipStatus: -0.01
# Correlation between LoanPurpose and MonthlyDebtPayments: -0.00
# Correlation between LoanPurpose and CreditCardUtilizationRate: 0.00
# Correlation between LoanPurpose and NumberOfOpenCreditLines: -0.00
# Correlation between LoanPurpose and NumberOfCreditInquiries: 0.00
# Correlation between LoanPurpose and DebtToIncomeRatio: -0.01
# Correlation between LoanPurpose and BankruptcyHistory: -0.00
# Correlation between LoanPurpose and PreviousLoanDefaults: -0.00
# Correlation between LoanPurpose and PaymentHistory: 0.01
# Correlation between LoanPurpose and LengthOfCreditHistory: -0.00
# Correlation between LoanPurpose and SavingsAccountBalance: 0.00
# Correlation between LoanPurpose and CheckingAccountBalance: 0.00
# Correlation between LoanPurpose and TotalAssets: 0.00
# Correlation between LoanPurpose and TotalLiabilities: -0.00
# Correlation between LoanPurpose and MonthlyIncome: -0.01
# Correlation between LoanPurpose and UtilityBillsPaymentHistory: -0.01
# Correlation between LoanPurpose and JobTenure: 0.00
# Correlation between LoanPurpose and NetWorth: 0.00
# Correlation between LoanPurpose and BaseInterestRate: 0.00
# Correlation between LoanPurpose and InterestRate: 0.00
# Correlation between LoanPurpose and MonthlyLoanPayment: 0.00
# Correlation between LoanPurpose and TotalDebtToIncomeRatio: 0.00
# Correlation between LoanPurpose and LoanApproved: -0.01
# Correlation between LoanPurpose and RiskScore: 0.01
# Correlation between PreviousLoanDefaults and Age: -0.00
# Correlation between PreviousLoanDefaults and AnnualIncome: 0.00
# Correlation between PreviousLoanDefaults and CreditScore: -0.01
# Correlation between PreviousLoanDefaults and EmploymentStatus: -0.01
# Correlation between PreviousLoanDefaults and EducationLevel: -0.00
# Correlation between PreviousLoanDefaults and Experience: -0.00
# Correlation between PreviousLoanDefaults and LoanAmount: -0.00
# Correlation between PreviousLoanDefaults and LoanDuration: 0.02
# Correlation between PreviousLoanDefaults and MaritalStatus: 0.01
# Correlation between PreviousLoanDefaults and NumberOfDependents: 0.01
# Correlation between PreviousLoanDefaults and HomeOwnershipStatus: 0.01
# Correlation between PreviousLoanDefaults and MonthlyDebtPayments: 0.00
# Correlation between PreviousLoanDefaults and CreditCardUtilizationRate: -0.00
# Correlation between PreviousLoanDefaults and NumberOfOpenCreditLines: 0.01
# Correlation between PreviousLoanDefaults and NumberOfCreditInquiries: -0.01
# Correlation between PreviousLoanDefaults and DebtToIncomeRatio: 0.01
# Correlation between PreviousLoanDefaults and BankruptcyHistory: -0.00
# Correlation between PreviousLoanDefaults and LoanPurpose: -0.00
# Correlation between PreviousLoanDefaults and PaymentHistory: 0.00
# Correlation between PreviousLoanDefaults and LengthOfCreditHistory: 0.01
# Correlation between PreviousLoanDefaults and SavingsAccountBalance: 0.00
# Correlation between PreviousLoanDefaults and CheckingAccountBalance: 0.01
# Correlation between PreviousLoanDefaults and TotalAssets: 0.01
# Correlation between PreviousLoanDefaults and TotalLiabilities: -0.00
# Correlation between PreviousLoanDefaults and MonthlyIncome: 0.00
# Correlation between PreviousLoanDefaults and UtilityBillsPaymentHistory: -0.01
# Correlation between PreviousLoanDefaults and JobTenure: 0.00
# Correlation between PreviousLoanDefaults and NetWorth: 0.01
# Correlation between PreviousLoanDefaults and BaseInterestRate: 0.01
# Correlation between PreviousLoanDefaults and InterestRate: 0.01
# Correlation between PreviousLoanDefaults and MonthlyLoanPayment: -0.01
# Correlation between PreviousLoanDefaults and TotalDebtToIncomeRatio: -0.00
# Correlation between PreviousLoanDefaults and LoanApproved: -0.07
# Correlation between PreviousLoanDefaults and RiskScore: 0.26
# Correlation between PaymentHistory and Age: -0.00
# Correlation between PaymentHistory and AnnualIncome: 0.00
# Correlation between PaymentHistory and CreditScore: 0.00
# Correlation between PaymentHistory and EmploymentStatus: 0.01
# Correlation between PaymentHistory and EducationLevel: -0.00
# Correlation between PaymentHistory and Experience: -0.00
# Correlation between PaymentHistory and LoanAmount: -0.00
# Correlation between PaymentHistory and LoanDuration: 0.00
# Correlation between PaymentHistory and MaritalStatus: 0.01
# Correlation between PaymentHistory and NumberOfDependents: 0.00
# Correlation between PaymentHistory and HomeOwnershipStatus: 0.00
# Correlation between PaymentHistory and MonthlyDebtPayments: -0.00
# Correlation between PaymentHistory and CreditCardUtilizationRate: 0.00
# Correlation between PaymentHistory and NumberOfOpenCreditLines: 0.00
# Correlation between PaymentHistory and NumberOfCreditInquiries: -0.00
# Correlation between PaymentHistory and DebtToIncomeRatio: -0.01
# Correlation between PaymentHistory and BankruptcyHistory: 0.01
# Correlation between PaymentHistory and LoanPurpose: 0.01
# Correlation between PaymentHistory and PreviousLoanDefaults: 0.00
# Correlation between PaymentHistory and LengthOfCreditHistory: 0.00
# Correlation between PaymentHistory and SavingsAccountBalance: -0.00
# Correlation between PaymentHistory and CheckingAccountBalance: -0.02
# Correlation between PaymentHistory and TotalAssets: -0.01
# Correlation between PaymentHistory and TotalLiabilities: -0.01
# Correlation between PaymentHistory and MonthlyIncome: 0.00
# Correlation between PaymentHistory and UtilityBillsPaymentHistory: 0.01
# Correlation between PaymentHistory and JobTenure: -0.01
# Correlation between PaymentHistory and NetWorth: -0.00
# Correlation between PaymentHistory and BaseInterestRate: -0.00
# Correlation between PaymentHistory and InterestRate: 0.00
# Correlation between PaymentHistory and MonthlyLoanPayment: -0.00
# Correlation between PaymentHistory and TotalDebtToIncomeRatio: 0.00
# Correlation between PaymentHistory and LoanApproved: 0.03
# Correlation between PaymentHistory and RiskScore: -0.02
# Correlation between LengthOfCreditHistory and Age: -0.00
# Correlation between LengthOfCreditHistory and AnnualIncome: -0.01
# Correlation between LengthOfCreditHistory and CreditScore: 0.01
# Correlation between LengthOfCreditHistory and EmploymentStatus: -0.00
# Correlation between LengthOfCreditHistory and EducationLevel: 0.00
# Correlation between LengthOfCreditHistory and Experience: -0.00
# Correlation between LengthOfCreditHistory and LoanAmount: 0.00
# Correlation between LengthOfCreditHistory and LoanDuration: 0.01
# Correlation between LengthOfCreditHistory and MaritalStatus: 0.00
# Correlation between LengthOfCreditHistory and NumberOfDependents: 0.00
# Correlation between LengthOfCreditHistory and HomeOwnershipStatus: 0.00
# Correlation between LengthOfCreditHistory and MonthlyDebtPayments: -0.00
# Correlation between LengthOfCreditHistory and CreditCardUtilizationRate: 0.01
# Correlation between LengthOfCreditHistory and NumberOfOpenCreditLines: 0.00
# Correlation between LengthOfCreditHistory and NumberOfCreditInquiries: -0.00
# Correlation between LengthOfCreditHistory and DebtToIncomeRatio: -0.00
# Correlation between LengthOfCreditHistory and BankruptcyHistory: 0.01
# Correlation between LengthOfCreditHistory and LoanPurpose: -0.00
# Correlation between LengthOfCreditHistory and PreviousLoanDefaults: 0.01
# Correlation between LengthOfCreditHistory and PaymentHistory: 0.00
# Correlation between LengthOfCreditHistory and SavingsAccountBalance: -0.01
# Correlation between LengthOfCreditHistory and CheckingAccountBalance: -0.00
# Correlation between LengthOfCreditHistory and TotalAssets: 0.00
# Correlation between LengthOfCreditHistory and TotalLiabilities: 0.00
# Correlation between LengthOfCreditHistory and MonthlyIncome: -0.01
# Correlation between LengthOfCreditHistory and UtilityBillsPaymentHistory: 0.01
# Correlation between LengthOfCreditHistory and JobTenure: 0.02
# Correlation between LengthOfCreditHistory and NetWorth: 0.00
# Correlation between LengthOfCreditHistory and BaseInterestRate: 0.00
# Correlation between LengthOfCreditHistory and InterestRate: 0.00
# Correlation between LengthOfCreditHistory and MonthlyLoanPayment: -0.01
# Correlation between LengthOfCreditHistory and TotalDebtToIncomeRatio: -0.01
# Correlation between LengthOfCreditHistory and LoanApproved: 0.11
# Correlation between LengthOfCreditHistory and RiskScore: -0.18
# Correlation between SavingsAccountBalance and Age: 0.00
# Correlation between SavingsAccountBalance and AnnualIncome: -0.00
# Correlation between SavingsAccountBalance and CreditScore: -0.01
# Correlation between SavingsAccountBalance and EmploymentStatus: 0.01
# Correlation between SavingsAccountBalance and EducationLevel: -0.00
# Correlation between SavingsAccountBalance and Experience: 0.01
# Correlation between SavingsAccountBalance and LoanAmount: 0.00
# Correlation between SavingsAccountBalance and LoanDuration: 0.00
# Correlation between SavingsAccountBalance and MaritalStatus: -0.01
# Correlation between SavingsAccountBalance and NumberOfDependents: -0.00
# Correlation between SavingsAccountBalance and HomeOwnershipStatus: -0.01
# Correlation between SavingsAccountBalance and MonthlyDebtPayments: -0.00
# Correlation between SavingsAccountBalance and CreditCardUtilizationRate: 0.00
# Correlation between SavingsAccountBalance and NumberOfOpenCreditLines: 0.01
# Correlation between SavingsAccountBalance and NumberOfCreditInquiries: -0.00
# Correlation between SavingsAccountBalance and DebtToIncomeRatio: -0.00
# Correlation between SavingsAccountBalance and BankruptcyHistory: 0.01
# Correlation between SavingsAccountBalance and LoanPurpose: 0.00
# Correlation between SavingsAccountBalance and PreviousLoanDefaults: 0.00
# Correlation between SavingsAccountBalance and PaymentHistory: -0.00
# Correlation between SavingsAccountBalance and LengthOfCreditHistory: -0.01
# Correlation between SavingsAccountBalance and CheckingAccountBalance: -0.00
# Correlation between SavingsAccountBalance and TotalAssets: 0.01
# Correlation between SavingsAccountBalance and TotalLiabilities: -0.00
# Correlation between SavingsAccountBalance and MonthlyIncome: -0.00
# Correlation between SavingsAccountBalance and UtilityBillsPaymentHistory: -0.01
# Correlation between SavingsAccountBalance and JobTenure: -0.00
# Correlation between SavingsAccountBalance and NetWorth: 0.00
# Correlation between SavingsAccountBalance and BaseInterestRate: 0.01
# Correlation between SavingsAccountBalance and InterestRate: 0.00
# Correlation between SavingsAccountBalance and MonthlyLoanPayment: 0.00
# Correlation between SavingsAccountBalance and TotalDebtToIncomeRatio: -0.00
# Correlation between SavingsAccountBalance and LoanApproved: 0.00
# Correlation between SavingsAccountBalance and RiskScore: 0.00
# Correlation between CheckingAccountBalance and Age: 0.01
# Correlation between CheckingAccountBalance and AnnualIncome: 0.01
# Correlation between CheckingAccountBalance and CreditScore: 0.01
# ...
# Correlation between JobTenure and InterestRate: -0.00
# Correlation between JobTenure and MonthlyLoanPayment: 0.00
# Correlation between JobTenure and TotalDebtToIncomeRatio: 0.01
# Correlation between JobTenure and LoanApproved: 0.00
# Correlation between JobTenure and RiskScore: -0.00
# Correlation between NetWorth and Age: 0.01
# Correlation between NetWorth and AnnualIncome: -0.00
# Correlation between NetWorth and CreditScore: 0.00
# Correlation between NetWorth and EmploymentStatus: -0.01
# Correlation between NetWorth and EducationLevel: 0.01
# Correlation between NetWorth and Experience: 0.02
# Correlation between NetWorth and LoanAmount: -0.00
# Correlation between NetWorth and LoanDuration: -0.01
# Correlation between NetWorth and MaritalStatus: -0.00
# Correlation between NetWorth and NumberOfDependents: -0.01
# Correlation between NetWorth and HomeOwnershipStatus: 0.01
# Correlation between NetWorth and MonthlyDebtPayments: 0.00
# Correlation between NetWorth and CreditCardUtilizationRate: -0.00
# Correlation between NetWorth and NumberOfOpenCreditLines: -0.00
# Correlation between NetWorth and NumberOfCreditInquiries: 0.00
# Correlation between NetWorth and DebtToIncomeRatio: -0.01
# Correlation between NetWorth and BankruptcyHistory: -0.00
# Correlation between NetWorth and LoanPurpose: 0.00
# Correlation between NetWorth and PreviousLoanDefaults: 0.01
# Correlation between NetWorth and PaymentHistory: -0.00
# Correlation between NetWorth and LengthOfCreditHistory: 0.00
# Correlation between NetWorth and SavingsAccountBalance: 0.00
# Correlation between NetWorth and CheckingAccountBalance: 0.00
# Correlation between NetWorth and TotalAssets: 0.98
# Correlation between NetWorth and TotalLiabilities: -0.13
# Correlation between NetWorth and MonthlyIncome: -0.00
# Correlation between NetWorth and UtilityBillsPaymentHistory: -0.00
# Correlation between NetWorth and JobTenure: 0.01
# Correlation between NetWorth and BaseInterestRate: -0.01
# Correlation between NetWorth and InterestRate: -0.01
# Correlation between NetWorth and MonthlyLoanPayment: 0.00
# Correlation between NetWorth and TotalDebtToIncomeRatio: -0.01
# Correlation between NetWorth and LoanApproved: 0.19
# Correlation between NetWorth and RiskScore: -0.30
# Correlation between BaseInterestRate and Age: -0.24
# Correlation between BaseInterestRate and AnnualIncome: -0.07
# Correlation between BaseInterestRate and CreditScore: -0.72
# Correlation between BaseInterestRate and EmploymentStatus: -0.01
# Correlation between BaseInterestRate and EducationLevel: -0.01
# Correlation between BaseInterestRate and Experience: -0.24
# Correlation between BaseInterestRate and LoanAmount: 0.39
# Correlation between BaseInterestRate and LoanDuration: 0.58
# Correlation between BaseInterestRate and MaritalStatus: 0.00
# Correlation between BaseInterestRate and NumberOfDependents: 0.01
# Correlation between BaseInterestRate and HomeOwnershipStatus: -0.01
# Correlation between BaseInterestRate and MonthlyDebtPayments: 0.00
# Correlation between BaseInterestRate and CreditCardUtilizationRate: 0.00
# Correlation between BaseInterestRate and NumberOfOpenCreditLines: 0.01
# Correlation between BaseInterestRate and NumberOfCreditInquiries: -0.00
# Correlation between BaseInterestRate and DebtToIncomeRatio: -0.00
# Correlation between BaseInterestRate and BankruptcyHistory: -0.00
# Correlation between BaseInterestRate and LoanPurpose: 0.00
# Correlation between BaseInterestRate and PreviousLoanDefaults: 0.01
# Correlation between BaseInterestRate and PaymentHistory: -0.00
# Correlation between BaseInterestRate and LengthOfCreditHistory: 0.00
# Correlation between BaseInterestRate and SavingsAccountBalance: 0.01
# Correlation between BaseInterestRate and CheckingAccountBalance: -0.00
# Correlation between BaseInterestRate and TotalAssets: -0.01
# Correlation between BaseInterestRate and TotalLiabilities: 0.01
# Correlation between BaseInterestRate and MonthlyIncome: -0.08
# Correlation between BaseInterestRate and UtilityBillsPaymentHistory: -0.01
# Correlation between BaseInterestRate and JobTenure: -0.00
# Correlation between BaseInterestRate and NetWorth: -0.01
# Correlation between BaseInterestRate and InterestRate: 0.83
# Correlation between BaseInterestRate and MonthlyLoanPayment: 0.12
# Correlation between BaseInterestRate and TotalDebtToIncomeRatio: 0.13
# Correlation between BaseInterestRate and LoanApproved: -0.25
# Correlation between BaseInterestRate and RiskScore: 0.26
# Correlation between InterestRate and Age: -0.20
# Correlation between InterestRate and AnnualIncome: -0.06
# Correlation between InterestRate and CreditScore: -0.60
# Correlation between InterestRate and EmploymentStatus: -0.01
# Correlation between InterestRate and EducationLevel: -0.00
# Correlation between InterestRate and Experience: -0.21
# Correlation between InterestRate and LoanAmount: 0.32
# Correlation between InterestRate and LoanDuration: 0.49
# Correlation between InterestRate and MaritalStatus: 0.00
# Correlation between InterestRate and NumberOfDependents: 0.01
# Correlation between InterestRate and HomeOwnershipStatus: -0.00
# Correlation between InterestRate and MonthlyDebtPayments: 0.00
# Correlation between InterestRate and CreditCardUtilizationRate: 0.00
# Correlation between InterestRate and NumberOfOpenCreditLines: 0.01
# Correlation between InterestRate and NumberOfCreditInquiries: -0.01
# Correlation between InterestRate and DebtToIncomeRatio: -0.01
# Correlation between InterestRate and BankruptcyHistory: 0.00
# Correlation between InterestRate and LoanPurpose: 0.00
# Correlation between InterestRate and PreviousLoanDefaults: 0.01
# Correlation between InterestRate and PaymentHistory: 0.00
# Correlation between InterestRate and LengthOfCreditHistory: 0.00
# Correlation between InterestRate and SavingsAccountBalance: 0.00
# Correlation between InterestRate and CheckingAccountBalance: -0.00
# Correlation between InterestRate and TotalAssets: -0.01
# Correlation between InterestRate and TotalLiabilities: 0.01
# Correlation between InterestRate and MonthlyIncome: -0.06
# Correlation between InterestRate and UtilityBillsPaymentHistory: -0.00
# Correlation between InterestRate and JobTenure: -0.00
# Correlation between InterestRate and NetWorth: -0.01
# Correlation between InterestRate and BaseInterestRate: 0.83
# Correlation between InterestRate and MonthlyLoanPayment: 0.13
# Correlation between InterestRate and TotalDebtToIncomeRatio: 0.13
# Correlation between InterestRate and LoanApproved: -0.30
# Correlation between InterestRate and RiskScore: 0.27
# Correlation between MonthlyLoanPayment and Age: -0.02
# Correlation between MonthlyLoanPayment and AnnualIncome: -0.00
# Correlation between MonthlyLoanPayment and CreditScore: -0.06
# Correlation between MonthlyLoanPayment and EmploymentStatus: 0.01
# Correlation between MonthlyLoanPayment and EducationLevel: 0.00
# Correlation between MonthlyLoanPayment and Experience: -0.02
# Correlation between MonthlyLoanPayment and LoanAmount: 0.78
# Correlation between MonthlyLoanPayment and LoanDuration: -0.39
# Correlation between MonthlyLoanPayment and MaritalStatus: 0.00
# Correlation between MonthlyLoanPayment and NumberOfDependents: -0.00
# Correlation between MonthlyLoanPayment and HomeOwnershipStatus: 0.01
# Correlation between MonthlyLoanPayment and MonthlyDebtPayments: 0.02
# Correlation between MonthlyLoanPayment and CreditCardUtilizationRate: 0.00
# Correlation between MonthlyLoanPayment and NumberOfOpenCreditLines: -0.01
# Correlation between MonthlyLoanPayment and NumberOfCreditInquiries: -0.00
# Correlation between MonthlyLoanPayment and DebtToIncomeRatio: -0.01
# Correlation between MonthlyLoanPayment and BankruptcyHistory: 0.01
# Correlation between MonthlyLoanPayment and LoanPurpose: 0.00
# Correlation between MonthlyLoanPayment and PreviousLoanDefaults: -0.01
# Correlation between MonthlyLoanPayment and PaymentHistory: -0.00
# Correlation between MonthlyLoanPayment and LengthOfCreditHistory: -0.01
# Correlation between MonthlyLoanPayment and SavingsAccountBalance: 0.00
# Correlation between MonthlyLoanPayment and CheckingAccountBalance: 0.00
# Correlation between MonthlyLoanPayment and TotalAssets: -0.00
# Correlation between MonthlyLoanPayment and TotalLiabilities: -0.00
# Correlation between MonthlyLoanPayment and MonthlyIncome: -0.01
# Correlation between MonthlyLoanPayment and UtilityBillsPaymentHistory: -0.01
# Correlation between MonthlyLoanPayment and JobTenure: 0.00
# Correlation between MonthlyLoanPayment and NetWorth: 0.00
# Correlation between MonthlyLoanPayment and BaseInterestRate: 0.12
# Correlation between MonthlyLoanPayment and InterestRate: 0.13
# Correlation between MonthlyLoanPayment and TotalDebtToIncomeRatio: 0.57
# Correlation between MonthlyLoanPayment and LoanApproved: -0.18
# Correlation between MonthlyLoanPayment and RiskScore: 0.12
# Correlation between TotalDebtToIncomeRatio and Age: -0.11
# Correlation between TotalDebtToIncomeRatio and AnnualIncome: -0.53
# Correlation between TotalDebtToIncomeRatio and CreditScore: -0.12
# Correlation between TotalDebtToIncomeRatio and EmploymentStatus: -0.01
# Correlation between TotalDebtToIncomeRatio and EducationLevel: 0.00
# Correlation between TotalDebtToIncomeRatio and Experience: -0.11
# Correlation between TotalDebtToIncomeRatio and LoanAmount: 0.46
# Correlation between TotalDebtToIncomeRatio and LoanDuration: -0.21
# Correlation between TotalDebtToIncomeRatio and MaritalStatus: 0.01
# Correlation between TotalDebtToIncomeRatio and NumberOfDependents: -0.00
# Correlation between TotalDebtToIncomeRatio and HomeOwnershipStatus: 0.00
# Correlation between TotalDebtToIncomeRatio and MonthlyDebtPayments: 0.22
# Correlation between TotalDebtToIncomeRatio and CreditCardUtilizationRate: 0.01
# Correlation between TotalDebtToIncomeRatio and NumberOfOpenCreditLines: 0.00
# Correlation between TotalDebtToIncomeRatio and NumberOfCreditInquiries: -0.00
# Correlation between TotalDebtToIncomeRatio and DebtToIncomeRatio: -0.01
# Correlation between TotalDebtToIncomeRatio and BankruptcyHistory: -0.00
# Correlation between TotalDebtToIncomeRatio and LoanPurpose: 0.00
# Correlation between TotalDebtToIncomeRatio and PreviousLoanDefaults: -0.00
# Correlation between TotalDebtToIncomeRatio and PaymentHistory: 0.00
# Correlation between TotalDebtToIncomeRatio and LengthOfCreditHistory: -0.01
# Correlation between TotalDebtToIncomeRatio and SavingsAccountBalance: -0.00
# Correlation between TotalDebtToIncomeRatio and CheckingAccountBalance: -0.01
# Correlation between TotalDebtToIncomeRatio and TotalAssets: -0.01
# Correlation between TotalDebtToIncomeRatio and TotalLiabilities: -0.00
# Correlation between TotalDebtToIncomeRatio and MonthlyIncome: -0.54
# Correlation between TotalDebtToIncomeRatio and UtilityBillsPaymentHistory: 0.01
# Correlation between TotalDebtToIncomeRatio and JobTenure: 0.01
# Correlation between TotalDebtToIncomeRatio and NetWorth: -0.01
# Correlation between TotalDebtToIncomeRatio and BaseInterestRate: 0.13
# Correlation between TotalDebtToIncomeRatio and InterestRate: 0.13
# Correlation between TotalDebtToIncomeRatio and MonthlyLoanPayment: 0.57
# Correlation between TotalDebtToIncomeRatio and LoanApproved: -0.41
# Correlation between TotalDebtToIncomeRatio and RiskScore: 0.34
# Correlation between LoanApproved and Age: 0.14
# Correlation between LoanApproved and AnnualIncome: 0.60
# Correlation between LoanApproved and CreditScore: 0.14
# Correlation between LoanApproved and EmploymentStatus: -0.02
# Correlation between LoanApproved and EducationLevel: 0.02
# Correlation between LoanApproved and Experience: 0.14
# Correlation between LoanApproved and LoanAmount: -0.24
# Correlation between LoanApproved and LoanDuration: -0.09
# Correlation between LoanApproved and MaritalStatus: -0.01
# Correlation between LoanApproved and NumberOfDependents: 0.00
# Correlation between LoanApproved and HomeOwnershipStatus: -0.02
# Correlation between LoanApproved and MonthlyDebtPayments: -0.07
# Correlation between LoanApproved and CreditCardUtilizationRate: -0.01
# Correlation between LoanApproved and NumberOfOpenCreditLines: -0.00
# Correlation between LoanApproved and NumberOfCreditInquiries: -0.01
# Correlation between LoanApproved and DebtToIncomeRatio: 0.00
# Correlation between LoanApproved and BankruptcyHistory: -0.07
# Correlation between LoanApproved and LoanPurpose: -0.01
# Correlation between LoanApproved and PreviousLoanDefaults: -0.07
# Correlation between LoanApproved and PaymentHistory: 0.03
# Correlation between LoanApproved and LengthOfCreditHistory: 0.11
# Correlation between LoanApproved and SavingsAccountBalance: 0.00
# Correlation between LoanApproved and CheckingAccountBalance: 0.00
# Correlation between LoanApproved and TotalAssets: 0.18
# Correlation between LoanApproved and TotalLiabilities: -0.03
# Correlation between LoanApproved and MonthlyIncome: 0.60
# Correlation between LoanApproved and UtilityBillsPaymentHistory: 0.00
# Correlation between LoanApproved and JobTenure: 0.00
# Correlation between LoanApproved and NetWorth: 0.19
# Correlation between LoanApproved and BaseInterestRate: -0.25
# Correlation between LoanApproved and InterestRate: -0.30
# Correlation between LoanApproved and MonthlyLoanPayment: -0.18
# Correlation between LoanApproved and TotalDebtToIncomeRatio: -0.41
# Correlation between LoanApproved and RiskScore: -0.77
# Correlation between RiskScore and Age: -0.16
# Correlation between RiskScore and AnnualIncome: -0.48
# Correlation between RiskScore and CreditScore: -0.24
# Correlation between RiskScore and EmploymentStatus: 0.13
# Correlation between RiskScore and EducationLevel: -0.02
# Correlation between RiskScore and Experience: -0.17
# Correlation between RiskScore and LoanAmount: 0.14
# Correlation between RiskScore and LoanDuration: 0.05
# Correlation between RiskScore and MaritalStatus: 0.02
# Correlation between RiskScore and NumberOfDependents: 0.00
# Correlation between RiskScore and HomeOwnershipStatus: 0.00
# Correlation between RiskScore and MonthlyDebtPayments: 0.04
# Correlation between RiskScore and CreditCardUtilizationRate: 0.11
# Correlation between RiskScore and NumberOfOpenCreditLines: 0.01
# Correlation between RiskScore and NumberOfCreditInquiries: 0.00
# Correlation between RiskScore and DebtToIncomeRatio: 0.33
# Correlation between RiskScore and BankruptcyHistory: 0.38
# Correlation between RiskScore and LoanPurpose: 0.01
# Correlation between RiskScore and PreviousLoanDefaults: 0.26
# Correlation between RiskScore and PaymentHistory: -0.02
# Correlation between RiskScore and LengthOfCreditHistory: -0.18
# Correlation between RiskScore and SavingsAccountBalance: 0.00
# Correlation between RiskScore and CheckingAccountBalance: -0.00
# Correlation between RiskScore and TotalAssets: -0.30
# Correlation between RiskScore and TotalLiabilities: 0.06
# Correlation between RiskScore and MonthlyIncome: -0.49
# Correlation between RiskScore and UtilityBillsPaymentHistory: -0.01
# Correlation between RiskScore and JobTenure: -0.00
# Correlation between RiskScore and NetWorth: -0.30
# Correlation between RiskScore and BaseInterestRate: 0.26
# Correlation between RiskScore and InterestRate: 0.27
# Correlation between RiskScore and MonthlyLoanPayment: 0.12
# Correlation between RiskScore and TotalDebtToIncomeRatio: 0.34
# Correlation between RiskScore and LoanApproved: -0.77
# {'Age': ['Experience'], 'AnnualIncome': ['MonthlyIncome'], 'CreditScore': [], 'EmploymentStatus': [], 'EducationLevel': [], 'Experience': ['Age'], 'LoanAmount': [], 'LoanDuration': [], 'MaritalStatus': [], 'NumberOfDependents': [], 'HomeOwnershipStatus': [], 'MonthlyDebtPayments': [], 'CreditCardUtilizationRate': [], 'NumberOfOpenCreditLines': [], 'NumberOfCreditInquiries': [], 'DebtToIncomeRatio': [], 'BankruptcyHistory': [], 'LoanPurpose': [], 'PreviousLoanDefaults': [], 'PaymentHistory': [], 'LengthOfCreditHistory': [], 'SavingsAccountBalance': [], 'CheckingAccountBalance': [], 'TotalAssets': ['NetWorth'], 'TotalLiabilities': [], 'MonthlyIncome': ['AnnualIncome'], 'UtilityBillsPaymentHistory': [], 'JobTenure': [], 'NetWorth': ['TotalAssets'], 'BaseInterestRate': ['InterestRate'], 'InterestRate': ['BaseInterestRate'], 'MonthlyLoanPayment': [], 'TotalDebtToIncomeRatio': [], 'LoanApproved': [], 'RiskScore': []}

# %% [markdown]
# #Relation Between All features and target

# %%
corrMatrix = copy.corr()

strongPositveCorr = []
strongPositveCorrWithOneColumn = {}
for i in corrMatrix.columns:

    if i==Y.name:
        continue
    if(corrMatrix.loc[i, Y.name]>=0.8):
        strongPositveCorr.append(i)
    print(f"Correlation between {i} and {Y.name}: {corrMatrix.loc[i, Y.name]:.2f}")
strongPositveCorrWithOneColumn[i] = strongPositveCorr
strongPositveCorr = []
    # We can do the same thing for moderate and weak corr
print(strongPositveCorrWithOneColumn)
# Out:
# Correlation between Age and RiskScore: -0.16
# Correlation between AnnualIncome and RiskScore: -0.48
# Correlation between CreditScore and RiskScore: -0.24
# Correlation between EmploymentStatus and RiskScore: 0.13
# Correlation between EducationLevel and RiskScore: -0.02
# Correlation between Experience and RiskScore: -0.17
# Correlation between LoanAmount and RiskScore: 0.14
# Correlation between LoanDuration and RiskScore: 0.05
# Correlation between MaritalStatus and RiskScore: 0.02
# Correlation between NumberOfDependents and RiskScore: 0.00
# Correlation between HomeOwnershipStatus and RiskScore: 0.00
# Correlation between MonthlyDebtPayments and RiskScore: 0.04
# Correlation between CreditCardUtilizationRate and RiskScore: 0.11
# Correlation between NumberOfOpenCreditLines and RiskScore: 0.01
# Correlation between NumberOfCreditInquiries and RiskScore: 0.00
# Correlation between DebtToIncomeRatio and RiskScore: 0.33
# Correlation between BankruptcyHistory and RiskScore: 0.38
# Correlation between LoanPurpose and RiskScore: 0.01
# Correlation between PreviousLoanDefaults and RiskScore: 0.26
# Correlation between PaymentHistory and RiskScore: -0.02
# Correlation between LengthOfCreditHistory and RiskScore: -0.18
# Correlation between SavingsAccountBalance and RiskScore: 0.00
# Correlation between CheckingAccountBalance and RiskScore: -0.00
# Correlation between TotalAssets and RiskScore: -0.30
# Correlation between TotalLiabilities and RiskScore: 0.06
# Correlation between MonthlyIncome and RiskScore: -0.49
# Correlation between UtilityBillsPaymentHistory and RiskScore: -0.01
# Correlation between JobTenure and RiskScore: -0.00
# Correlation between NetWorth and RiskScore: -0.30
# Correlation between BaseInterestRate and RiskScore: 0.26
# Correlation between InterestRate and RiskScore: 0.27
# Correlation between MonthlyLoanPayment and RiskScore: 0.12
# Correlation between TotalDebtToIncomeRatio and RiskScore: 0.34
# Correlation between LoanApproved and RiskScore: -0.77
# {'RiskScore': []}

# %% [markdown]
# #Training

# %%
X_train, X_test, y_train, y_test = train_test_split(
    scaledX, scaledY, test_size=0.20, random_state=0)

# %% [markdown]
# #To show the best model

# %%
models_Errors = {}

# %% [markdown]
# #Linear Regression

# %% [markdown]
# Fitting

# %%
linear_reg = LinearRegression()
linear_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Prediction

# %%
yhat = linear_reg.predict(X_test)

# %% [markdown]
# Evaluation

# %%
MSE = mean_squared_error(y_test,yhat)
RMSE = root_mean_squared_error(y_test,yhat)
MAE = mean_absolute_error(y_test,yhat)
r2Score = r2_score(y_test,yhat)
Errors = {}
Errors['MSE'] = MSE
Errors['RMSE'] = RMSE
Errors['MAE'] = MAE
Errors['r2_Score'] = r2Score
models_Errors['Linear Regression'] = Errors
print("Metrics for Linear Regression")
print(tabulate.tabulate(models_Errors["Linear Regression"].items(), headers=["Metric", "Value"], tablefmt="grid",floatfmt=".5f"))
# Out:
# Metrics for Linear Regression
# +----------+---------+
# | Metric   |   Value |
# +==========+=========+
# | MSE      | 0.03577 |
# +----------+---------+
# | RMSE     | 0.18912 |
# +----------+---------+
# | MAE      | 0.14924 |
# +----------+---------+
# | r2_Score | 0.94164 |
# +----------+---------+

# %% [markdown]
# #KNN

# %%
k_values = list(range(1, 25))
mse_values = []
KNNErrors = {}
for k in k_values:
  #Fitting
  knn_model = KNeighborsRegressor(n_neighbors=k)
  knn_model.fit(X_train, y_train)
  #predection
  yhat = knn_model.predict(X_test)
  #Evaluation
  metricsPerK = {}
  mse = mean_squared_error(y_test, yhat)
  mse_values.append(mse)
  MSE = mean_squared_error(y_test,yhat)
  RMSE = root_mean_squared_error(y_test,yhat)
  MAE = mean_absolute_error(y_test,yhat)
  r2Score = r2_score(y_test,yhat)
  metricsPerK['MSE'] = MSE
  metricsPerK['RMSE'] = RMSE
  metricsPerK['MAE'] = MAE
  metricsPerK['r2Score'] = r2Score
  KNNErrors[k] = metricsPerK

print(tabulate.tabulate(KNNErrors.items(), headers=["K Value", "Metrics"], tablefmt="grid",floatfmt=".5f"))
# Out:
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |   K Value | Metrics                                                                                                              |
# +===========+======================================================================================================================+
# |         1 | {'MSE': 0.36225609999999997, 'RMSE': 0.6018771469328271, 'MAE': 0.434705, 'r2Score': 0.40895994711983785}            |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |         2 | {'MSE': 0.26873947499999995, 'RMSE': 0.5184008825223969, 'MAE': 0.3786575, 'r2Score': 0.5615372839408721}            |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |         3 | {'MSE': 0.2427867111111111, 'RMSE': 0.49273391512165177, 'MAE': 0.36002666666666666, 'r2Score': 0.6038805955960113}  |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |         4 | {'MSE': 0.23073988125, 'RMSE': 0.4803539124957764, 'MAE': 0.35079125, 'r2Score': 0.6235356378662433}                 |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |         5 | {'MSE': 0.220114656, 'RMSE': 0.46916378376852574, 'MAE': 0.343042, 'r2Score': 0.6408712567657557}                    |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |         6 | {'MSE': 0.21576915, 'RMSE': 0.46450958009496424, 'MAE': 0.33799833333333335, 'r2Score': 0.6479611804303429}          |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |         7 | {'MSE': 0.2130593285714286, 'RMSE': 0.4615835011906606, 'MAE': 0.3358878571428571, 'r2Score': 0.6523823979072567}    |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |         8 | {'MSE': 0.2114989453125, 'RMSE': 0.4598901448308063, 'MAE': 0.334921875, 'r2Score': 0.6549282460071797}              |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |         9 | {'MSE': 0.20958254691358025, 'RMSE': 0.45780186425306335, 'MAE': 0.33304611111111115, 'r2Score': 0.6580549517025067} |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        10 | {'MSE': 0.2098604, 'RMSE': 0.45810522808629894, 'MAE': 0.33301800000000004, 'r2Score': 0.6576016196457368}           |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        11 | {'MSE': 0.20946066198347107, 'RMSE': 0.45766872515332646, 'MAE': 0.3329768181818181, 'r2Score': 0.6582538134346818}  |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        12 | {'MSE': 0.20957786180555552, 'RMSE': 0.45779674726406205, 'MAE': 0.33258708333333337, 'r2Score': 0.658062595704898}  |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        13 | {'MSE': 0.20945119289940825, 'RMSE': 0.4576583801258404, 'MAE': 0.33256, 'r2Score': 0.6582692627478756}              |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        14 | {'MSE': 0.20968521428571427, 'RMSE': 0.45791398131714023, 'MAE': 0.33273, 'r2Score': 0.6578874444360863}             |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        15 | {'MSE': 0.20993510755555553, 'RMSE': 0.45818676056337065, 'MAE': 0.3326006666666667, 'r2Score': 0.6574797303039532}  |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        16 | {'MSE': 0.20967002539062496, 'RMSE': 0.45789739613872554, 'MAE': 0.33309468750000004, 'r2Score': 0.6579122259245326} |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        17 | {'MSE': 0.21007436193771625, 'RMSE': 0.45833869784005393, 'MAE': 0.33347470588235295, 'r2Score': 0.6572525293889209} |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        18 | {'MSE': 0.21042489166666667, 'RMSE': 0.45872093005079534, 'MAE': 0.33298416666666664, 'r2Score': 0.6566806215327524} |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        19 | {'MSE': 0.210693756232687, 'RMSE': 0.4590138954679771, 'MAE': 0.3335010526315789, 'r2Score': 0.6562419547240548}     |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        20 | {'MSE': 0.211464425, 'RMSE': 0.4598526122574493, 'MAE': 0.333746, 'r2Score': 0.6549845677290924}                     |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        21 | {'MSE': 0.21207649569160997, 'RMSE': 0.4605176388495993, 'MAE': 0.33449761904761904, 'r2Score': 0.6539859419117893}  |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        22 | {'MSE': 0.21194422210743802, 'RMSE': 0.4603740024235057, 'MAE': 0.3345779545454545, 'r2Score': 0.6542017532844167}   |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        23 | {'MSE': 0.2123058570888469, 'RMSE': 0.4607665971930332, 'MAE': 0.3346665217391304, 'r2Score': 0.6536117266194821}    |
# +-----------+----------------------------------------------------------------------------------------------------------------------+
# |        24 | {'MSE': 0.21284670642361112, 'RMSE': 0.46135312551624824, 'MAE': 0.33541020833333335, 'r2Score': 0.6527293022257472} |
# +-----------+----------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# Best K using linegraph

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, mse_values, marker='o', linestyle='-', color='b')
plt.xticks(k_values)
plt.xlabel('(k)')
plt.ylabel('MSE')
plt.title('MSE vs. K')
plt.show()

# %% [markdown]
# Best K according to MSE Value

# %%
winnerK = ""
scores = float("inf")
for k, metrics in KNNErrors.items():
    if metrics["MSE"] < scores:
        winnerK = k
        scores = metrics["MSE"]

print(f"The best k is: {winnerK}")
print(f"Metrics at K = {winnerK}:")
for metrics,value in KNNErrors[winnerK].items():
    print(f"{metrics}: {value}")
models_Errors['KNN'] = KNNErrors[winnerK]
# Out:
# The best k is: 13
# Metrics at K = 13:
# MSE: 0.20945119289940825
# RMSE: 0.4576583801258404
# MAE: 0.33256
# r2Score: 0.6582692627478756

# %% [markdown]
# #Ridge

# %% [markdown]
# Fitting

# %%
RG = Ridge()
RG.fit(X_train,y_train)
# Out:
# Ridge()

# %% [markdown]
# Prediction

# %%
yhat = RG.predict(X_test)

# %% [markdown]
# Evaluation

# %%
MSE = mean_squared_error(y_test,yhat)
RMSE = root_mean_squared_error(y_test,yhat)
MAE = mean_absolute_error(y_test,yhat)
r2Score = r2_score(y_test,yhat)
Errors = {}
Errors['MSE'] = MSE
Errors['RMSE'] = RMSE
Errors['MAE'] = MAE
Errors['r2_Score'] = r2Score
models_Errors['Ridge'] = Errors
print("Metrics for ridger")
print(tabulate.tabulate(models_Errors['Ridge'].items(), headers=["Metric", "Value"], tablefmt="grid",floatfmt=".5f"))
# Out:
# Metrics for ridger
# +----------+---------+
# | Metric   |   Value |
# +==========+=========+
# | MSE      | 0.03551 |
# +----------+---------+
# | RMSE     | 0.18844 |
# +----------+---------+
# | MAE      | 0.14860 |
# +----------+---------+
# | r2_Score | 0.94206 |
# +----------+---------+

# %% [markdown]
# #Scores for all Models and winner Model

# %%
for model,metrics in models_Errors.items():
    print(model)
    print(tabulate.tabulate(metrics.items(), headers=["Metric", "Value"], tablefmt="grid",floatfmt=".5f"))
# Out:
# Linear Regression
# +----------+---------+
# | Metric   |   Value |
# +==========+=========+
# | MSE      | 0.03577 |
# +----------+---------+
# | RMSE     | 0.18912 |
# +----------+---------+
# | MAE      | 0.14924 |
# +----------+---------+
# | r2_Score | 0.94164 |
# +----------+---------+
# KNN
# +----------+---------+
# | Metric   |   Value |
# +==========+=========+
# | MSE      | 0.20945 |
# +----------+---------+
# | RMSE     | 0.45766 |
# +----------+---------+
# | MAE      | 0.33256 |
# +----------+---------+
# | r2Score  | 0.65827 |
# +----------+---------+
# Ridge
# +----------+---------+
# | Metric   |   Value |
# +==========+=========+
# | MSE      | 0.03551 |
# +----------+---------+
# | RMSE     | 0.18844 |
# +----------+---------+
# | MAE      | 0.14860 |
# +----------+---------+
# | r2_Score | 0.94206 |
# +----------+---------+

# %% [markdown]
# The Winner Model Scores

# %%
winnerModel = ""
scores = float("inf")
for model, metrics in models_Errors.items():
    if metrics["MSE"] < scores:
        winnerModel = model
        scores = metrics["MSE"]

# %%
import tabulate
print(f"The winner model is {winnerModel}")
print(f"Metrics for {winnerModel}:")
print(tabulate.tabulate((models_Errors[winnerModel].items()), headers=["Metric", "Value"], tablefmt="grid",floatfmt=".5f"))
# Out:
# The winner model is Ridge
# Metrics for Ridge:
# +----------+---------+
# | Metric   |   Value |
# +==========+=========+
# | MSE      | 0.03551 |
# +----------+---------+
# | RMSE     | 0.18844 |
# +----------+---------+
# | MAE      | 0.14860 |
# +----------+---------+
# | r2_Score | 0.94206 |
# +----------+---------+
